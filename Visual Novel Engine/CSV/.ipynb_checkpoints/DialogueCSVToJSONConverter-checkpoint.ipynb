# %%
import os
import glob
import pandas as pd
import numpy as np
import json

# %%
filekeys = open('dialoguekeys.txt').read().splitlines()
#filetextkeys = [x + '.txt' for x in filekeys]
print(filekeys)
# Out:
# ['Dialogue_TestIntro']

# %%
inputPath = 'E:/Users/William/Documents/GitHub/Visual Novel Engine/CSV'
outputPath = 'E:/Users/William/Documents/GitHub/Visual Novel Engine/Assets/RawData/DialogueData'
metaHeader = ['routeKey', 'setting']
dataHeader = ['id', 'route', 'speakerName', 'sprite', 'text', 'choices']

for key in filekeys:
    # Header
    header = pd.read_csv(key + '.csv', names=metaHeader, nrows=3)
    header = header.to_json(orient='records')
    #header = json.loads(header)
    print('\nHeader\n{0}'.format(header))
    
    # Dialogue
    dialogueFile = pd.read_csv(key + '.csv', skiprows=3, names=dataHeader, header=None)
    dialogueFile = dialogueFile.fillna('')
    dialogueFile = dialogueFile.to_dict(orient='records') # KEY CONVERSION
    dialogueDict = {"data": dialogueFile}
    #dialogueDict = json.loads(dialogueDict)
    
    print('\nFile Data\n{0}'.format(dialogueFile))
    
    # Print to file
    with open(outputPath + '/' + key + '_meta.json', "w+") as outfile:
        json.dump(header, outfile, indent=4)
        print('\nHeader Json\n{0}'.format(json.dumps(header, indent=4, separators=(',', ': '))))
        
    with open(outputPath + '/' + key + '_data.json', "w+") as outfile:
        json.dump(dialogueDict, outfile, indent=4)
        print('\nData Json\n{0}'.format(json.dumps(dialogueDict, indent=4, separators=(',', ': '))))
# Out:
# Header
# [{"routeKey":null,"setting":null},{"routeKey":null,"setting":null},{"routeKey":"Text","setting":"Choices"}]
#
# File Data
# [{'id': 0, 'route': '', 'speakerName': 'Character A', 'sprite': '', 'text': 'Text.', 'choices': ''}, {'id': 1, 'route': '', 'speakerName': 'Character A', 'sprite': '', 'text': 'More text.', 'choices': ''}, {'id': 2, 'route': '', 'speakerName': 'Character B', 'sprite': '', 'text': 'New text.', 'choices': ''}, {'id': 3, 'route': '', 'speakerName': 'Character C', 'sprite': '', 'text': 'What will you choose?', 'choices': 'A / B / C'}, {'id': 4, 'route': 'A', 'speakerName': 'Character C', 'sprite': '', 'text': "You've chosen A.", 'choices': ''}, {'id': 4, 'route': 'B', 'speakerName': 'Character C', 'sprite': '', 'text': "You've chosen B.", 'choices': ''}, {'id': 4, 'route': 'C', 'speakerName': 'Character C', 'sprite': '', 'text': "You've chosen C.", 'choices': ''}, {'id': 5, 'route': '', 'speakerName': 'Character A', 'sprite': '', 'text': "You've reach back to a merging point.", 'choices': ''}, {'id': 6, 'route': '', 'speakerName': 'Joyce', 'sprite': '', 'text': 'So what will it be?', 'choices': 'Belgium waffles / Bacon and eggs'}, {'id': 7, 'route': 'Belgium waffles', 'speakerName': 'Max', 'sprite': '', 'text': 'Belgium waffles,fgfd', 'choices': ''}, {'id': 7, 'route': 'Bacon and eggs', 'speakerName': 'Max', 'sprite': '', 'text': 'Bacon and eggs.', 'choices': ''}]
#
# Header Json
# "[{\"routeKey\":null,\"setting\":null},{\"routeKey\":null,\"setting\":null},{\"routeKey\":\"Text\",\"setting\":\"Choices\"}]"
#
# Data Json
# {
#     "data": [
#         {
#             "id": 0,
#             "route": "",
#             "speakerName": "Character A",
#             "sprite": "",
#             "text": "Text.",
#             "choices": ""
#         },
#         {
#             "id": 1,
#             "route": "",
#             "speakerName": "Character A",
#             "sprite": "",
#             "text": "More text.",
#             "choices": ""
#         },
#         {
#             "id": 2,
#             "route": "",
#             "speakerName": "Character B",
#             "sprite": "",
#             "text": "New text.",
#             "choices": ""
#         },
#         {
#             "id": 3,
#             "route": "",
#             "speakerName": "Character C",
#             "sprite": "",
#             "text": "What will you choose?",
#             "choices": "A / B / C"
#         },
#         {
#             "id": 4,
#             "route": "A",
#             "speakerName": "Character C",
#             "sprite": "",
#             "text": "You've chosen A.",
#             "choices": ""
#         },
#         {
#             "id": 4,
#             "route": "B",
#             "speakerName": "Character C",
#             "sprite": "",
#             "text": "You've chosen B.",
#             "choices": ""
#         },
#         {
#             "id": 4,
#             "route": "C",
#             "speakerName": "Character C",
#             "sprite": "",
#             "text": "You've chosen C.",
#             "choices": ""
#         },
#         {
#             "id": 5,
#             "route": "",
#             "speakerName": "Character A",
#             "sprite": "",
#             "text": "You've reach back to a merging point.",
#             "choices": ""
#         },
#         {
#             "id": 6,
#             "route": "",
#             "speakerName": "Joyce",
#             "sprite": "",
#             "text": "So what will it be?",
#             "choices": "Belgium waffles / Bacon and eggs"
#         },
#         {
#             "id": 7,
#             "route": "Belgium waffles",
#             "speakerName": "Max",
#             "sprite": "",
#             "text": "Belgium waffles,fgfd",
#             "choices": ""
#         },
#         {
#             "id": 7,
#             "route": "Bacon and eggs",
#             "speakerName": "Max",
#             "sprite": "",
#             "text": "Bacon and eggs.",
#             "choices": ""
#         }
#     ]
# }
